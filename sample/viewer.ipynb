# %%
import json
import pandas as pd
import matplotlib.pyplot as plt

# %%
with open('../output/sample.json', 'r') as stream:
    data = json.load(stream)

# %%
meta = data['meta']

# %%
df = pd.DataFrame(data['sampling'])

xLabel = 'Timestamp'
yLabel1 = 'JSHeapTotalSize'
yLabel2 = 'JSHeapUsedSize'

# %%
# 補間
xArray = df[xLabel] - df[xLabel][0]

# %%
plt.plot(xArray, df[yLabel2], '-x', label=yLabel2)
plt.xlabel(xLabel + " [sec]")
plt.ylabel(yLabel2)
plt.show()

# %%
plt.plot(xArray, df[yLabel], '-x', label=yLabel)
plt.xlabel(xLabel + " [sec]")
plt.ylabel(yLabel)
plt.show()
